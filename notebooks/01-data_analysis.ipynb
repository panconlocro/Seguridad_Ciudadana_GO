# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/Crime_Data_from_2020_to_Present.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1005198 entries, 0 to 1005197
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1005198 non-null  int64
#  1   Date Rptd       1005198 non-null  str
#  2   DATE OCC        1005198 non-null  str
#  3   TIME OCC        1005198 non-null  int64
#  4   AREA            1005198 non-null  int64
#  5   AREA NAME       1005198 non-null  str
#  6   Rpt Dist No     1005198 non-null  int64
#  7   Part 1-2        1005198 non-null  int64
#  8   Crm Cd          1005198 non-null  int64
#  9   Crm Cd Desc     1005198 non-null  str
#  10  Mocodes         853438 non-null   str
#  11  Vict Age        1005198 non-null  int64
#  12  Vict Sex        860416 non-null   str
#  13  Vict Descent    860404 non-null   str
#  14  Premis Cd       1005182 non-null  float64
#  15  Premis Desc     1004610 non-null  str
#  16  Weapon Used Cd  327280 non-null   float64
# ...

# %%
df.sample(5)
# Out:
#             DR_NO        Date Rptd         DATE OCC  TIME OCC  AREA  \
# 706750  231804991   1/19/2023 0:00   1/19/2023 0:00      1400    18
# 432913  220106091    2/8/2022 0:00    2/2/2022 0:00      2300     1
# 329719  210807747    4/4/2021 0:00   3/29/2021 0:00      1635     8
# 619893  220123744  10/31/2022 0:00  10/30/2022 0:00      1935     1
# 239681  210618949  11/12/2021 0:00  11/12/2021 0:00      1335     6
#
#         AREA NAME  Rpt Dist No  Part 1-2  Crm Cd            Crm Cd Desc  ...  \
# 706750  Southeast         1801         1     510       VEHICLE - STOLEN  ...
# 432913    Central          165         1     510       VEHICLE - STOLEN  ...
# 329719    West LA          808         2     888            TRESPASSING  ...
# 619893    Central          152         1     330  BURGLARY FROM VEHICLE  ...
# 239681  Hollywood          636         1     648                  ARSON  ...
#
#        Status  Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# ...

# %%
# ver cuantos valores unicos hay en la columna 'Status Desc'
valores_unicos = df['Status Desc'].unique()
print("Valores únicos:", valores_unicos)
# Out:
# Valores únicos: <StringArray>
# ['Adult Arrest', 'Invest Cont', 'Adult Other', 'Juv Arrest', 'Juv Other',
#  'UNK']
# Length: 6, dtype: str
